# %%
import pandas as pd
x=pd.read_csv("/content/archive.zip")
print(x.isnull())

a=x['longitude']
print(a.describe)
b=x['latitude']
print(b.describe)
c=x['housing_median_age']
print(c.describe)
e=x['total_bedrooms']
print(e.describe)
f=x['population']
print(f.describe)
g=x['households']
print(g.describe)
h=x['median_income']
print(h.describe)
i=x['median_house_value']
print(i.describe)
j=x['ocean_proximity']
print(j.describe)


a=x['longitude']
print(type(a))
b=x['latitude']
print(type(b))
c=x['housing_median_age']
print(type(c))
e=x['total_bedrooms']
print(type(e))
f=x['population']
print(type(f))
g=x['households']
print(type(g))
h=x['median_income']
print(type(h))
i=x['median_house_value']
print(type(i))
j=x['ocean_proximity']
print(type(j))

a=x['longitude']
print(a.shape)
b=x['latitude']
print(b.shape)
c=x['housing_median_age']
print(c.shape)
e=x['total_bedrooms']
print(e.shape)
f=x['population']
print(f.shape)
g=x['households']
print(g.shape)
h=x['median_income']
print(h.shape)
i=x['median_house_value']
print(i.shape)
j=x['ocean_proximity']
print(j.shape)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
import pandas as pd
a=pd.read_csv("/content/head (1).csv")
print(a)
d=a['Head Size(cm^3)']
print(d)


import numpy as np
mi=min(d)
ma=max(d)
print(mi)
print(ma)
for i in range(0,236):
  nm=(d[i]-mi)/(ma-mi)
  print(nm)


import numpy as np
import pandas as pd
head=pd.read_csv('/content/head (1).csv')
head_size=head['Head Size(cm^3)']
print(head_size)
print(min(head_size))
print(max(head_size))
print((head_size-min(head_size))/(max(head_size)-min(head_size)))
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]
# 0      4512
# 1      3738
# 2      4261
# 3      3777
# 4      4177
#        ...
# 232    3214
# 233    3394
# 234    3233
# 235    3352
# 236    3391
# Name: Head Size(cm^3), Length: 237, dtype: int64
# 2720
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
a=pd.read_csv('/content/archive (5).zip')
#b,c,d,e,f,g,h=a['longitude'],a['total_rooms'],a['latitude'],a['households'],a['population'],a['total_bedrooms'],a['housing_median_age']
q = a.drop("median_house_value", axis=1)
x=q.drop("ocean_proximity",axis=1)
y= a["median_house_value"]
print(x)
print(y)
scaler = MinMaxScaler()
scaler.fit(x)
x_scaled = scaler.transform(x)
print(x_scaled)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income
# ...
